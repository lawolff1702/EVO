# %%
import torch
import gc
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import random

# %load_ext autoreload
# %autoreload 2

from EVO import LogisticRegression, DeepNeuralNetwork, EvolutionOptimizer, GradientDescentOptimizer

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps"  if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def classification_data(n_points=1000, p_dims=2, noise=0.2, add_bias=True):
    torch.manual_seed(0)
    X = torch.randn(n_points, p_dims)
    true_w = torch.randn(p_dims + 1)
    if add_bias:
        X_with_bias = torch.cat([X, torch.ones(n_points, 1)], dim=1)
        logits = X_with_bias @ true_w
    else:
        logits = X @ true_w[:-1] + true_w[-1]
    probs = torch.sigmoid(logits)
    y = (probs + noise * torch.randn(n_points)).clamp(0, 1).round()
    return (X_with_bias if add_bias else X).float(), y.float()

# %%
def accuracy(model, X, y):
    y_pred = model.predict(X)
    y = y.to(y_pred.device)  # Match device
    return (y_pred == y).float().mean().item()

# %%
def run_experiment(num_parents_list, model_class, optimizer_class, X, y):
    results = {}
    for num_parents in num_parents_list:
        print(f"\nTesting with {num_parents} parents...")

        model = model_class()
        optimizer = optimizer_class(model)
        optimizer.set_population_size(50)
        optimizer.set_mutation_rate(0.5)
        optimizer.set_mutation_intensity(0.3)
        model.set_optimizer(optimizer)

        losses = []
        accs = []
        diversities = []

        max_iter = 300
        for i in range(max_iter):
            acc = accuracy(model, X, y)
            loss = model.loss(X, y).item()
            diversity = optimizer.compute_diversity(metric = "euclidean").item()

            losses.append(loss)
            accs.append(acc)
            diversities.append(diversity)

            if acc > 0.99:
                print(f"Early stop at iter {i} with acc {acc:.3f}")
                break

            optimizer.step(X, y, num_parents=num_parents)

            if i % 100 == 0:
                print(f"Iter {i}: loss {loss:.4f}, acc {acc:.4f}, diversity {diversity:.4f}")

        final_loss = losses[-1]
        print(f"Final loss with {num_parents} parents: {final_loss:.4f}")
        
        results[num_parents] = (losses, accs, diversities)

    return results

# %%
def plot_results(results):
    plt.figure(figsize=(12, 5))
    
    for num_parents, (losses, accs) in results.items():
        plt.plot(accs, label=f"{num_parents} parents")
    
    plt.title("Accuracy over Iterations")
    plt.xlabel("Iteration")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
X, y = classification_data(p_dims=2, noise=0.2, n_points=300, add_bias=False)

y = y.long()  

num_parents_list = [0, 1, 2, 3, 5, 10]
results = run_experiment(num_parents_list, lambda: DeepNeuralNetwork([2, 10, 2]), EvolutionOptimizer, X, y)
# Out:
# Testing with 0 parents...
# Iter 0: loss 0.6079, acc 0.6700, diversity 0.0000
# Iter 100: loss 0.2961, acc 0.8733, diversity 2.9197
# Iter 200: loss 0.2961, acc 0.8733, diversity 2.9584
# Final loss with 0 parents: 0.2961
#
# Testing with 1 parents...
# Iter 0: loss 1.3892, acc 0.1433, diversity 0.0000
# Iter 100: loss 0.2595, acc 0.9233, diversity 4.9949
# Iter 200: loss 0.2595, acc 0.9233, diversity 5.5162
# Final loss with 1 parents: 0.2565
#
# Testing with 2 parents...
# Iter 0: loss 0.4565, acc 0.8733, diversity 0.0000
# Iter 100: loss 0.2668, acc 0.9200, diversity 8.0457
# Iter 200: loss 0.2668, acc 0.9200, diversity 8.7269
# Final loss with 2 parents: 0.2657
#
# Testing with 3 parents...
# Iter 0: loss 0.6194, acc 0.7667, diversity 0.0000
# Iter 100: loss 0.2658, acc 0.9200, diversity 8.7939
# Iter 200: loss 0.2658, acc 0.9200, diversity 8.7175
# Final loss with 3 parents: 0.2658
#
# Testing with 5 parents...
# Iter 0: loss 0.7873, acc 0.4533, diversity 0.0000
# Iter 100: loss 0.2598, acc 0.9000, diversity 7.9550
# Iter 200: loss 0.2598, acc 0.9000, diversity 8.0586
# Final loss with 5 parents: 0.2598
#
# Testing with 10 parents...
# Iter 0: loss 1.2965, acc 0.1267, diversity 0.0000
# Iter 100: loss 0.2776, acc 0.9067, diversity 8.0027
# Iter 200: loss 0.2665, acc 0.9033, diversity 8.4250
# Final loss with 10 parents: 0.2536

# %%
for num_parents, (losses, accs, diversities) in results.items():
    print(f"{num_parents} parents → Final loss: {losses[-1]:.4f}, Final acc: {accs[-1]:.4f}, Final diversity: {diversities[-1]:.4f}")
# Out:
# 0 parents → Final loss: 0.2961, Final acc: 0.8733, Final diversity: 2.9419
# 1 parents → Final loss: 0.2565, Final acc: 0.9167, Final diversity: 6.4722
# 2 parents → Final loss: 0.2657, Final acc: 0.9200, Final diversity: 8.6953
# 3 parents → Final loss: 0.2658, Final acc: 0.9200, Final diversity: 8.8287
# 5 parents → Final loss: 0.2598, Final acc: 0.9000, Final diversity: 8.8498
# 10 parents → Final loss: 0.2536, Final acc: 0.9067, Final diversity: 8.1135

# %%
def plot_diversity(results):
    plt.figure(figsize=(12, 5))
    for num_parents, (_, _, diversities) in results.items():
        plt.plot(diversities, label=f"{num_parents} parents")
    plt.title("Diversity over Iterations")
    plt.xlabel("Iteration")
    plt.ylabel("Diversity")
    plt.legend()
    plt.grid(True)
    plt.show()
plot_diversity(results)

# %%
def plot_all_metrics(results):
    import matplotlib.pyplot as plt

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    for num_parents, (losses, accs, diversities) in results.items():
        axs[0].plot(losses, label=f"{num_parents} parents")
        axs[1].plot(accs, label=f"{num_parents} parents")
        axs[2].plot(diversities, label=f"{num_parents} parents")

    axs[0].set_title("Loss over Iterations")
    axs[0].set_xlabel("Iteration")
    axs[0].set_ylabel("Loss")
    axs[0].grid(True)

    axs[1].set_title("Accuracy over Iterations")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("Accuracy")
    axs[1].grid(True)

    axs[2].set_title("Diversity over Iterations")
    axs[2].set_xlabel("Iteration")
    axs[2].set_ylabel("Diversity")
    axs[2].grid(True)

    axs[0].legend()
    plt.tight_layout()
    plt.show()
plot_all_metrics(results)

# %%
def plot_all_metrics(results):
    import matplotlib.pyplot as plt

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    for num_parents, (losses, accs, diversities) in results.items():
        axs[0].plot(losses[:51], label=f"{num_parents} parents")
        axs[1].plot(accs[:51], label=f"{num_parents} parents")
        axs[2].plot(diversities[:51], label=f"{num_parents} parents")

    axs[0].set_title("Loss over Iterations")
    axs[0].set_xlabel("Iteration")
    axs[0].set_ylabel("Loss")
    axs[0].set_xlim(0, 50)
    axs[0].grid(True)

    axs[1].set_title("Accuracy over Iterations")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("Accuracy")
    axs[1].set_xlim(0, 50)
    axs[1].grid(True)

    axs[2].set_title("Diversity over Iterations")
    axs[2].set_xlabel("Iteration")
    axs[2].set_ylabel("Diversity")
    axs[2].set_xlim(0, 50)
    axs[2].grid(True)

    axs[0].legend()
    plt.tight_layout()
    plt.show()
plot_all_metrics(results)

# %% [markdown]
# Load in MNIST data:

# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
from EVO import DeepNeuralNetwork, EvolutionOptimizer, LogisticRegression

device = torch.device("cuda" if torch.cuda.is_available()
                      else ("mps" if torch.backends.mps.is_available() else "cpu"))

def flatten_tensor(x):
    return x.view(-1)

transform = transforms.Compose([
    transforms.ToTensor(),                        # (1, 28, 28) in [0,1]
    transforms.Normalize((0.1307,), (0.3081,)),   # standard MNIST normalisation
    transforms.Lambda(flatten_tensor),       # flatten to (784,)
])



train_ds = Subset(
    datasets.MNIST(".", train=True, download=True, transform=transform),
    range(1000)
)
test_ds = Subset(
    datasets.MNIST(".", train=False, download=True, transform=transform),
    range(1000)
)

train_loader = DataLoader(
    train_ds, batch_size=256, shuffle=True,
    num_workers=4, pin_memory=True
)
test_loader = DataLoader(
    test_ds, batch_size=1000,
    num_workers=2, pin_memory=True
)

# %% [markdown]
# Set up the model

# %% [markdown]
# Evolution Loop

# %%
num_parents_list = [0, 1, 2, 5, 10]

results = {}
for num_parents in num_parents_list:
    print(f"\nTesting with {num_parents} parents...")

    model = DeepNeuralNetwork([784, 32, 10])
    model.use_diversity_loss = True
    model.diversity_coeff   = 0.2

    optimizer = EvolutionOptimizer(model)
    optimizer.set_population_size(100)
    optimizer.use_backprop = False
    optimizer.set_survivors_ratio(0.1)
    optimizer.set_fitness_ratio(0.5)
    optimizer.set_sneaker_prob(0.01)
    optimizer.set_sneakers_ratio(0.1)
    optimizer.set_mutation_intensity(0.05)
    optimizer.mutation_rate = 0.05
    optimizer.set_num_parents(num_parents)


    losses = []
    accuracies = []
    diversities = []
    for gen in range(1000):
        for X, y in train_loader:
            optimizer.step(X, y)
        # optionally decay diversity over time
        model.diversity_coeff *= 0.9

        # evaluate on test set
        correct = total = 0
        with torch.no_grad():
            for X, y in test_loader:
                preds = model.predict(X.to(device))
                correct += (preds == y.to(device)).sum().item()
                total   += y.size(0)
        acc = 100 * correct / total
        losses.append(model.loss(X, y).item())
        diversities.append(optimizer.compute_diversity(metric = "euclidean").item())
        accuracies.append(acc)
        results[num_parents] = (losses, accuracies, diversities)
        if gen%25 == 0:
            print(f"Gen {gen+1:03d} → Test Acc: {acc:.2f}%, Loss: {losses[-1]:.4f}, Diversity: {diversities[-1]:.4f}")
    print(f"Final Test Acc: {acc:.2f}%, Loss: {losses[-1]:.4f}, Diversity: {diversities[-1]:.4f}")
# Out:
# Testing with 0 parents...
# Gen 001 → Test Acc: 6.30%, Loss: -13.6381, Diversity: 65.1011
# Gen 026 → Test Acc: 4.50%, Loss: 11.2207, Diversity: 65.1282
# Gen 051 → Test Acc: 12.30%, Loss: 11.4443, Diversity: 65.1214
# Gen 076 → Test Acc: 12.30%, Loss: 11.5845, Diversity: 65.1222
# Gen 101 → Test Acc: 12.30%, Loss: 11.5946, Diversity: 65.1323
# Gen 126 → Test Acc: 12.40%, Loss: 12.8119, Diversity: 65.1358
# Gen 151 → Test Acc: 12.30%, Loss: 11.5953, Diversity: 65.1228
# Gen 176 → Test Acc: 12.40%, Loss: 12.8120, Diversity: 65.1262
# Gen 201 → Test Acc: 5.50%, Loss: 14.4539, Diversity: 65.1240
# Gen 226 → Test Acc: 19.40%, Loss: 12.7083, Diversity: 65.1448
# Gen 251 → Test Acc: 19.40%, Loss: 12.7083, Diversity: 65.1021
# Gen 276 → Test Acc: 19.40%, Loss: 12.7083, Diversity: 65.1375
# Gen 301 → Test Acc: 19.40%, Loss: 12.7083, Diversity: 65.1535
# Gen 326 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1420
# Gen 351 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1194
# Gen 376 → Test Acc: 10.50%, Loss: 12.0157, Diversity: 65.1542
# Gen 401 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1528
# Gen 426 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1397
# Gen 451 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1310
# Gen 476 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1177
# Gen 501 → Test Acc: 11.30%, Loss: 10.3038, Diversity: 65.1492
# Gen 526 → Test Acc: 15.60%, Loss: 11.3447, Diversity: 65.1270
# Gen 551 → Test Acc: 15.60%, Loss: 11.3447, Diversity: 65.1297
# Gen 576 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1287
# Gen 601 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1522
# Gen 626 → Test Acc: 10.50%, Loss: 12.0157, Diversity: 65.1143
# Gen 651 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1266
# Gen 676 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1398
# Gen 701 → Test Acc: 15.20%, Loss: 10.0428, Diversity: 65.1405
# Gen 726 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1245
# Gen 751 → Test Acc: 15.20%, Loss: 10.0428, Diversity: 65.1298
# Gen 776 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1313
# Gen 801 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1134
# Gen 826 → Test Acc: 15.20%, Loss: 10.0428, Diversity: 65.1352
# Gen 851 → Test Acc: 15.20%, Loss: 10.0428, Diversity: 65.1032
# Gen 876 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1337
# Gen 901 → Test Acc: 7.80%, Loss: 11.7770, Diversity: 65.1245
# Gen 926 → Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.0916
# Gen 951 → Test Acc: 15.20%, Loss: 10.0428, Diversity: 65.1161
# Gen 976 → Test Acc: 10.80%, Loss: 10.8919, Diversity: 65.1238
# Final Test Acc: 6.10%, Loss: 10.4148, Diversity: 65.1244
#
# Testing with 1 parents...
# Gen 001 → Test Acc: 10.10%, Loss: -3.5358, Diversity: 52.7764
# Gen 026 → Test Acc: 18.40%, Loss: 7.4096, Diversity: 8.0919
# Gen 051 → Test Acc: 18.20%, Loss: 6.1279, Diversity: 12.2137
# Gen 076 → Test Acc: 19.50%, Loss: 5.7511, Diversity: 10.7363
# Gen 101 → Test Acc: 21.50%, Loss: 5.7346, Diversity: 8.1912
# Gen 126 → Test Acc: 25.10%, Loss: 5.7878, Diversity: 11.5267
# Gen 151 → Test Acc: 26.70%, Loss: 4.7596, Diversity: 8.9848
# Gen 176 → Test Acc: 26.30%, Loss: 4.7719, Diversity: 8.4514
# Gen 201 → Test Acc: 24.80%, Loss: 5.7258, Diversity: 8.3904
# Gen 226 → Test Acc: 29.70%, Loss: 4.9142, Diversity: 8.3708
# Gen 251 → Test Acc: 29.00%, Loss: 5.0775, Diversity: 8.7210
# Gen 276 → Test Acc: 29.70%, Loss: 5.1084, Diversity: 7.9055
# Gen 301 → Test Acc: 31.00%, Loss: 5.0940, Diversity: 8.4289
# Gen 326 → Test Acc: 31.50%, Loss: 5.1409, Diversity: 8.6760
# Gen 351 → Test Acc: 38.20%, Loss: 5.2780, Diversity: 9.4174
# Gen 376 → Test Acc: 32.10%, Loss: 5.1611, Diversity: 9.1640
# Gen 401 → Test Acc: 33.60%, Loss: 4.9140, Diversity: 8.5761
# Gen 426 → Test Acc: 34.10%, Loss: 4.8101, Diversity: 8.8233
# Gen 451 → Test Acc: 33.80%, Loss: 4.8400, Diversity: 8.3676
# Gen 476 → Test Acc: 34.70%, Loss: 4.9508, Diversity: 8.0372
# Gen 501 → Test Acc: 33.50%, Loss: 5.0124, Diversity: 11.6587
# Gen 526 → Test Acc: 32.60%, Loss: 5.9124, Diversity: 7.5467
# Gen 551 → Test Acc: 32.30%, Loss: 5.5899, Diversity: 10.1062
# Gen 576 → Test Acc: 34.40%, Loss: 5.1880, Diversity: 10.1156
# Gen 601 → Test Acc: 34.20%, Loss: 5.0304, Diversity: 8.6853
# Gen 626 → Test Acc: 43.40%, Loss: 5.2495, Diversity: 10.7650
# Gen 651 → Test Acc: 34.60%, Loss: 5.2490, Diversity: 8.3740
# Gen 676 → Test Acc: 35.10%, Loss: 5.0707, Diversity: 9.7455
# Gen 701 → Test Acc: 33.60%, Loss: 5.3743, Diversity: 11.1333
# Gen 726 → Test Acc: 34.90%, Loss: 5.5983, Diversity: 11.9425
# Gen 751 → Test Acc: 35.60%, Loss: 5.4968, Diversity: 10.3369
# Gen 776 → Test Acc: 36.40%, Loss: 5.2226, Diversity: 8.5158
# Gen 801 → Test Acc: 34.80%, Loss: 5.4879, Diversity: 8.4483
# Gen 826 → Test Acc: 35.10%, Loss: 5.8779, Diversity: 15.5372
# Gen 851 → Test Acc: 36.70%, Loss: 5.9073, Diversity: 9.9732
# Gen 876 → Test Acc: 35.60%, Loss: 5.7775, Diversity: 9.6356
# Gen 901 → Test Acc: 36.70%, Loss: 5.8218, Diversity: 10.5574
# Gen 926 → Test Acc: 36.50%, Loss: 5.8632, Diversity: 11.0725
# Gen 951 → Test Acc: 35.20%, Loss: 6.4864, Diversity: 9.1261
# Gen 976 → Test Acc: 37.00%, Loss: 5.9915, Diversity: 8.7081
# Final Test Acc: 33.40%, Loss: 6.7708, Diversity: 12.3895
#
# Testing with 2 parents...
# Gen 001 → Test Acc: 8.20%, Loss: -12.3162, Diversity: 62.7064
# Gen 026 → Test Acc: 21.00%, Loss: 6.8953, Diversity: 26.7652
# Gen 051 → Test Acc: 22.10%, Loss: 6.0417, Diversity: 17.5229
# Gen 076 → Test Acc: 25.70%, Loss: 5.3603, Diversity: 15.2781
# Gen 101 → Test Acc: 27.00%, Loss: 5.3645, Diversity: 13.0129
# Gen 126 → Test Acc: 27.50%, Loss: 5.1403, Diversity: 12.9137
# Gen 151 → Test Acc: 28.40%, Loss: 4.8067, Diversity: 12.9266
# Gen 176 → Test Acc: 27.50%, Loss: 4.8654, Diversity: 12.7925
# Gen 201 → Test Acc: 30.20%, Loss: 4.8025, Diversity: 13.7509
# Gen 226 → Test Acc: 30.60%, Loss: 4.7552, Diversity: 15.0691
# Gen 251 → Test Acc: 31.80%, Loss: 4.6030, Diversity: 14.7138
# Gen 276 → Test Acc: 32.30%, Loss: 4.8051, Diversity: 12.5925
# Gen 301 → Test Acc: 29.50%, Loss: 4.7708, Diversity: 14.1881
# Gen 326 → Test Acc: 32.50%, Loss: 4.6209, Diversity: 13.6826
# Gen 351 → Test Acc: 33.60%, Loss: 4.3932, Diversity: 12.5741
# Gen 376 → Test Acc: 33.60%, Loss: 4.2558, Diversity: 14.1832
# Gen 401 → Test Acc: 34.80%, Loss: 4.2542, Diversity: 13.9879
# Gen 426 → Test Acc: 32.90%, Loss: 4.4421, Diversity: 13.4361
# Gen 451 → Test Acc: 35.20%, Loss: 3.9637, Diversity: 12.3094
# Gen 476 → Test Acc: 35.70%, Loss: 4.3478, Diversity: 12.2569
# Gen 501 → Test Acc: 35.40%, Loss: 4.1350, Diversity: 13.5549
# Gen 526 → Test Acc: 36.30%, Loss: 3.9983, Diversity: 14.1525
# Gen 551 → Test Acc: 37.60%, Loss: 4.0696, Diversity: 14.8382
# Gen 576 → Test Acc: 37.30%, Loss: 4.4384, Diversity: 12.2224
# Gen 601 → Test Acc: 38.90%, Loss: 4.0992, Diversity: 13.5783
# Gen 626 → Test Acc: 36.00%, Loss: 4.6176, Diversity: 15.0009
# Gen 651 → Test Acc: 36.60%, Loss: 5.2173, Diversity: 14.6575
# Gen 676 → Test Acc: 38.50%, Loss: 4.3002, Diversity: 14.9517
# Gen 701 → Test Acc: 39.40%, Loss: 4.4374, Diversity: 13.7966
# Gen 726 → Test Acc: 41.20%, Loss: 4.3362, Diversity: 15.1217
# Gen 751 → Test Acc: 40.80%, Loss: 4.3291, Diversity: 16.4382
# Gen 776 → Test Acc: 40.90%, Loss: 4.2741, Diversity: 15.1502
# Gen 801 → Test Acc: 40.70%, Loss: 4.4170, Diversity: 13.0308
# Gen 826 → Test Acc: 39.70%, Loss: 4.7295, Diversity: 17.0918
# Gen 851 → Test Acc: 40.40%, Loss: 4.5571, Diversity: 15.2889
# Gen 876 → Test Acc: 42.20%, Loss: 4.1629, Diversity: 15.7567
# Gen 901 → Test Acc: 42.20%, Loss: 4.4854, Diversity: 16.6049
# Gen 926 → Test Acc: 48.70%, Loss: 4.2523, Diversity: 16.6533
# Gen 951 → Test Acc: 48.70%, Loss: 4.5993, Diversity: 16.0621
# Gen 976 → Test Acc: 47.80%, Loss: 4.5194, Diversity: 16.7433
# Final Test Acc: 48.10%, Loss: 5.1838, Diversity: 14.6372
#
# Testing with 5 parents...
# Gen 001 → Test Acc: 4.50%, Loss: -9.9846, Diversity: 62.8940
# Gen 026 → Test Acc: 14.60%, Loss: 5.4172, Diversity: 38.4148
# Gen 051 → Test Acc: 17.00%, Loss: 5.9308, Diversity: 26.5057
# Gen 076 → Test Acc: 24.00%, Loss: 5.1505, Diversity: 20.8359
# Gen 101 → Test Acc: 22.80%, Loss: 5.0911, Diversity: 19.7632
# Gen 126 → Test Acc: 25.00%, Loss: 4.4220, Diversity: 18.9481
# Gen 151 → Test Acc: 27.80%, Loss: 4.2584, Diversity: 19.2089
# Gen 176 → Test Acc: 27.10%, Loss: 4.1068, Diversity: 18.4974
# Gen 201 → Test Acc: 29.90%, Loss: 4.2508, Diversity: 18.2383
# Gen 226 → Test Acc: 30.60%, Loss: 4.0560, Diversity: 18.6778
# Gen 251 → Test Acc: 30.60%, Loss: 3.9317, Diversity: 18.8468
# Gen 276 → Test Acc: 31.80%, Loss: 4.3696, Diversity: 18.5794
# Gen 301 → Test Acc: 33.70%, Loss: 4.5682, Diversity: 18.5758
# Gen 326 → Test Acc: 34.80%, Loss: 3.6694, Diversity: 17.7689
# Gen 351 → Test Acc: 37.40%, Loss: 3.8520, Diversity: 18.1983
# Gen 376 → Test Acc: 42.50%, Loss: 4.2235, Diversity: 18.6758
# Gen 401 → Test Acc: 43.00%, Loss: 3.7842, Diversity: 18.4592
# Gen 426 → Test Acc: 43.60%, Loss: 4.0871, Diversity: 19.0143
# Gen 451 → Test Acc: 44.70%, Loss: 3.6214, Diversity: 19.1079
# Gen 476 → Test Acc: 43.60%, Loss: 4.2258, Diversity: 19.9363
# Gen 501 → Test Acc: 44.20%, Loss: 3.9734, Diversity: 19.3258
# Gen 526 → Test Acc: 43.00%, Loss: 4.0512, Diversity: 19.1516
# Gen 551 → Test Acc: 46.20%, Loss: 3.4226, Diversity: 19.0757
# Gen 576 → Test Acc: 45.10%, Loss: 4.0351, Diversity: 19.7056
# Gen 601 → Test Acc: 45.40%, Loss: 4.0951, Diversity: 18.9137
# Gen 626 → Test Acc: 47.30%, Loss: 4.0555, Diversity: 18.3161
# Gen 651 → Test Acc: 44.80%, Loss: 4.4851, Diversity: 19.6048
# Gen 676 → Test Acc: 46.40%, Loss: 4.5048, Diversity: 21.0403
# Gen 701 → Test Acc: 47.00%, Loss: 4.0684, Diversity: 19.9119
# Gen 726 → Test Acc: 48.40%, Loss: 4.1961, Diversity: 20.4433
# Gen 751 → Test Acc: 47.60%, Loss: 4.7368, Diversity: 21.1373
# Gen 776 → Test Acc: 48.10%, Loss: 5.0613, Diversity: 21.5200
# Gen 801 → Test Acc: 49.60%, Loss: 5.3721, Diversity: 21.3026
# Gen 826 → Test Acc: 50.60%, Loss: 4.8426, Diversity: 21.5724
# Gen 851 → Test Acc: 47.70%, Loss: 5.5539, Diversity: 22.0808
# Gen 876 → Test Acc: 47.70%, Loss: 5.1197, Diversity: 21.3398
# Gen 901 → Test Acc: 49.10%, Loss: 5.1674, Diversity: 21.4375
# Gen 926 → Test Acc: 50.70%, Loss: 5.1083, Diversity: 21.7204
# Gen 951 → Test Acc: 49.80%, Loss: 6.0058, Diversity: 21.0995
# Gen 976 → Test Acc: 51.90%, Loss: 4.9907, Diversity: 22.3749
# Final Test Acc: 51.50%, Loss: 5.6343, Diversity: 22.4986
#
# Testing with 10 parents...
# Gen 001 → Test Acc: 9.00%, Loss: -9.1322, Diversity: 62.8655
# Gen 026 → Test Acc: 15.40%, Loss: 8.1796, Diversity: 36.4265
# Gen 051 → Test Acc: 21.00%, Loss: 6.2666, Diversity: 25.3973
# Gen 076 → Test Acc: 24.20%, Loss: 5.2379, Diversity: 21.6467
# Gen 101 → Test Acc: 26.40%, Loss: 5.2853, Diversity: 20.3900
# Gen 126 → Test Acc: 26.40%, Loss: 4.9419, Diversity: 19.6482
# Gen 151 → Test Acc: 28.90%, Loss: 4.8341, Diversity: 18.9695
# Gen 176 → Test Acc: 27.50%, Loss: 4.6787, Diversity: 18.9758
# Gen 201 → Test Acc: 30.10%, Loss: 4.6913, Diversity: 18.5995
# Gen 226 → Test Acc: 31.60%, Loss: 4.3211, Diversity: 18.9937
# Gen 251 → Test Acc: 33.20%, Loss: 4.6607, Diversity: 18.9956
# Gen 276 → Test Acc: 32.80%, Loss: 4.1720, Diversity: 18.8439
# Gen 301 → Test Acc: 32.80%, Loss: 4.6732, Diversity: 19.0197
# Gen 326 → Test Acc: 32.30%, Loss: 4.2239, Diversity: 19.0043
# Gen 351 → Test Acc: 33.80%, Loss: 4.3743, Diversity: 19.2180
# Gen 376 → Test Acc: 36.90%, Loss: 4.0183, Diversity: 19.2679
# Gen 401 → Test Acc: 35.60%, Loss: 4.1386, Diversity: 18.9502
# Gen 426 → Test Acc: 34.30%, Loss: 5.1381, Diversity: 19.3564
# Gen 451 → Test Acc: 37.60%, Loss: 3.7763, Diversity: 19.5194
# Gen 476 → Test Acc: 36.20%, Loss: 3.8905, Diversity: 19.1153
# Gen 501 → Test Acc: 36.50%, Loss: 3.7646, Diversity: 18.9281
# Gen 526 → Test Acc: 36.50%, Loss: 3.7646, Diversity: 18.8666
# Gen 551 → Test Acc: 35.20%, Loss: 4.1016, Diversity: 18.8478
# Gen 576 → Test Acc: 36.80%, Loss: 4.2996, Diversity: 18.7291
# Gen 601 → Test Acc: 36.00%, Loss: 4.1944, Diversity: 18.6683
# Gen 626 → Test Acc: 36.30%, Loss: 4.2975, Diversity: 18.7836
# Gen 651 → Test Acc: 35.40%, Loss: 4.3830, Diversity: 20.0207
# Gen 676 → Test Acc: 35.40%, Loss: 4.7522, Diversity: 19.6960
# Gen 701 → Test Acc: 37.50%, Loss: 4.4887, Diversity: 20.3032
# Gen 726 → Test Acc: 36.40%, Loss: 4.4593, Diversity: 20.0168
# Gen 751 → Test Acc: 37.50%, Loss: 4.4357, Diversity: 21.0687
# Gen 776 → Test Acc: 39.20%, Loss: 4.4919, Diversity: 21.2783
# Gen 801 → Test Acc: 37.60%, Loss: 4.8343, Diversity: 21.4385
# Gen 826 → Test Acc: 38.00%, Loss: 5.4229, Diversity: 21.1335
# Gen 851 → Test Acc: 38.80%, Loss: 5.4365, Diversity: 22.0769
# Gen 876 → Test Acc: 39.70%, Loss: 4.7619, Diversity: 21.7713
# Gen 901 → Test Acc: 41.80%, Loss: 4.6070, Diversity: 22.2188
# Gen 926 → Test Acc: 48.70%, Loss: 5.5098, Diversity: 22.0923
# Gen 951 → Test Acc: 48.70%, Loss: 5.3026, Diversity: 22.0604
# Gen 976 → Test Acc: 49.50%, Loss: 5.6423, Diversity: 21.9321
# Final Test Acc: 49.20%, Loss: 5.8128, Diversity: 21.7539

# %%
def plot_all_metrics(results):
    import matplotlib.pyplot as plt

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    for num_parents, (losses, accs, diversities) in results.items():
        axs[0].plot(losses, label=f"{num_parents} parents")
        axs[1].plot(accs, label=f"{num_parents} parents")
        axs[2].plot(diversities, label=f"{num_parents} parents")

    axs[0].set_title("Loss over Iterations")
    axs[0].set_xlabel("Iteration")
    axs[0].set_ylabel("Loss")
    axs[0].grid(True)

    axs[1].set_title("Accuracy over Iterations")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("Accuracy")
    axs[1].grid(True)

    axs[2].set_title("Diversity over Iterations")
    axs[2].set_xlabel("Iteration")
    axs[2].set_ylabel("Diversity")
    axs[2].grid(True)

    axs[0].legend()
    plt.tight_layout()
    plt.show()
plot_all_metrics(results)

# %%
for num_parents, (losses, accs, diversities) in results.items():
    final_acc = accs[-1]
    final_loss = losses[-1]
    final_diversity = diversities[-1]
    print(f"{num_parents} parents → Final Acc: {final_acc:.2f}, Loss: {final_loss:.4f}, Diversity: {final_diversity:.4f}")
# Out:
# 0 parents → Final Acc: 6.10, Loss: 10.4148, Diversity: 65.1244
# 1 parents → Final Acc: 33.40, Loss: 6.7708, Diversity: 12.3895
# 2 parents → Final Acc: 48.10, Loss: 5.1838, Diversity: 14.6372
# 5 parents → Final Acc: 51.50, Loss: 5.6343, Diversity: 22.4986
# 10 parents → Final Acc: 49.20, Loss: 5.8128, Diversity: 21.7539
